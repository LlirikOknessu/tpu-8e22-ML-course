# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
print("TensorFlow version:", tf.__version__)
# %load_ext tensorboard
import datetime
import shutil
# Out:
# TensorFlow version: 2.18.0
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %reload_ext tensorboard
from tensorflow.keras import Model
from pathlib import Path
import pandas as pd

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 128
LEARNING_RATE = 0.05
EPOCHS = 50

# %%
input_dir = Path('./data/prepared')
logs_path = Path('./data/logs')
if logs_path.exists():
  shutil.rmtree(logs_path)
logs_path.mkdir(parents=True)

X_train_name = input_dir / 'X_train.csv'
y_train_name = input_dir / 'y_train.csv'
X_test_name = input_dir / 'X_test.csv'
y_test_name = input_dir / 'y_test.csv'

X_train = pd.read_csv(X_train_name)
y_train = pd.read_csv(y_train_name)
X_test = pd.read_csv(X_test_name)
y_test = pd.read_csv(y_test_name)

train_ds = tf.data.Dataset.from_tensor_slices(
    (X_train, y_train)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
  
  
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
from tensorflow.keras.layers import Dense, Input

def create_model():
    model = tf.keras.models.Sequential([
        Input(shape=(7,)),  
        Dense(128, activation='relu'), 
        Dense(64, activation='relu'), 
        Dense(1, activation='linear')
    ])
    return model

# %%
model = create_model()

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %%
logdir = logs_path / 'new_log'
logdir.mkdir(exist_ok=True, parents=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=str(logdir),
    histogram_freq=1,  # Записывать гистограммы весов каждые 1 эпоху
    write_graph=True,  # Включить сохранение графа
    write_images=True  # Сохранение весов как изображений
)

# %%
model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=100,
    callbacks=[tensorboard_callback]
)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1644.4640 - mae: 35.6210 - val_loss: 143.9030 - val_mae: 10.8444
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 79.0457 - mae: 7.3717 - val_loss: 28.9146 - val_mae: 4.3415
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.6341 - mae: 3.7243 - val_loss: 17.9144 - val_mae: 3.4873
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.1686 - mae: 3.3280 - val_loss: 17.6989 - val_mae: 3.4662
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.8281 - mae: 3.3174 - val_loss: 17.7367 - val_mae: 3.4606
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.9469 - mae: 3.3220 - val_loss: 17.3606 - val_mae: 3.4247
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.6944 - mae: 3.2879 - val_loss: 17.3277 - val_mae: 3.4157
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.3132 - mae: 3.2554 - val_loss: 17.2441 - val_mae: 3.4016
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.3635 - mae: 3.2583 - val_loss: 16.9928 - val_mae: 3.3743
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1519 - mae: 3.2299 - val_loss: 16.7930 - val_mae: 3.3505
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.9788 - mae: 3.2193 - val_loss: 16.3628 - val_mae: 3.3061
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.7580 - mae: 3.1884 - val_loss: 16.0675 - val_mae: 3.2719
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.3610 - mae: 3.1513 - val_loss: 15.8678 - val_mae: 3.2461
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.1557 - mae: 3.1268 - val_loss: 15.4356 - val_mae: 3.1941
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.9378 - mae: 3.1129 - val_loss: 15.0179 - val_mae: 3.1469
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.4748 - mae: 3.0424 - val_loss: 14.5480 - val_mae: 3.0917
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.0841 - mae: 3.0128 - val_loss: 14.1218 - val_mae: 3.0357
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.4698 - mae: 2.9329 - val_loss: 13.6433 - val_mae: 2.9782
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.0533 - mae: 2.8922 - val_loss: 13.2086 - val_mae: 2.9246
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.8779 - mae: 2.8681 - val_loss: 12.7570 - val_mae: 2.8667
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.2818 - mae: 2.7936 - val_loss: 12.3259 - val_mae: 2.8058
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.0729 - mae: 2.7855 - val_loss: 12.3903 - val_mae: 2.8014
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.8435 - mae: 2.7604 - val_loss: 11.4297 - val_mae: 2.6891
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.1249 - mae: 2.6652 - val_loss: 11.8264 - val_mae: 2.7164
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.2729 - mae: 2.6754 - val_loss: 10.8399 - val_mae: 2.6007
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.4314 - mae: 2.5853 - val_loss: 10.4950 - val_mae: 2.5484
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.5610 - mae: 2.5784 - val_loss: 10.3736 - val_mae: 2.5321
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.2151 - mae: 2.5490 - val_loss: 10.5626 - val_mae: 2.5611
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.3094 - mae: 2.5674 - val_loss: 10.5587 - val_mae: 2.5636
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3699 - mae: 2.5778 - val_loss: 9.9796 - val_mae: 2.4740
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8185 - mae: 2.5032 - val_loss: 9.9415 - val_mae: 2.4699
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9293 - mae: 2.5133 - val_loss: 9.7504 - val_mae: 2.4327
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4952 - mae: 2.4539 - val_loss: 9.7947 - val_mae: 2.4479
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6109 - mae: 2.4616 - val_loss: 9.8994 - val_mae: 2.4722
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7336 - mae: 2.4739 - val_loss: 9.6920 - val_mae: 2.4316
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3805 - mae: 2.4455 - val_loss: 9.6083 - val_mae: 2.4120
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7643 - mae: 2.5007 - val_loss: 10.4228 - val_mae: 2.5530
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7606 - mae: 2.5101 - val_loss: 10.3180 - val_mae: 2.5382
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7989 - mae: 2.4984 - val_loss: 10.3593 - val_mae: 2.5442
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7263 - mae: 2.5053 - val_loss: 9.9506 - val_mae: 2.4820
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4734 - mae: 2.4610 - val_loss: 9.6277 - val_mae: 2.4253
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4714 - mae: 2.4617 - val_loss: 9.8249 - val_mae: 2.4610
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6167 - mae: 2.4804 - val_loss: 10.2486 - val_mae: 2.5256
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6006 - mae: 2.4922 - val_loss: 9.5689 - val_mae: 2.4096
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2650 - mae: 2.4402 - val_loss: 10.4299 - val_mae: 2.5497
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.7474 - mae: 2.5136 - val_loss: 9.6477 - val_mae: 2.4280
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3420 - mae: 2.4529 - val_loss: 11.1020 - val_mae: 2.6403
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.3144 - mae: 2.6001 - val_loss: 9.6293 - val_mae: 2.4240
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9733 - mae: 2.5178 - val_loss: 9.6585 - val_mae: 2.4299
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4047 - mae: 2.4620 - val_loss: 9.5135 - val_mae: 2.3993
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2587 - mae: 2.4405 - val_loss: 9.4813 - val_mae: 2.3930
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4038 - mae: 2.4492 - val_loss: 9.7089 - val_mae: 2.4380
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3956 - mae: 2.4365 - val_loss: 9.7841 - val_mae: 2.4499
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4862 - mae: 2.4645 - val_loss: 9.4292 - val_mae: 2.3747
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4387 - mae: 2.4308 - val_loss: 9.5559 - val_mae: 2.4071
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3333 - mae: 2.4534 - val_loss: 9.4228 - val_mae: 2.3814
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1248 - mae: 2.4179 - val_loss: 9.4702 - val_mae: 2.3904
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5398 - mae: 2.4694 - val_loss: 9.3786 - val_mae: 2.3708
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2149 - mae: 2.4222 - val_loss: 9.3831 - val_mae: 2.3738
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1276 - mae: 2.4148 - val_loss: 10.1528 - val_mae: 2.5062
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6140 - mae: 2.4866 - val_loss: 9.8515 - val_mae: 2.4610
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1604 - mae: 2.4240 - val_loss: 10.7000 - val_mae: 2.5838
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9629 - mae: 2.5294 - val_loss: 10.1056 - val_mae: 2.5001
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0294 - mae: 2.5253 - val_loss: 9.3385 - val_mae: 2.3673
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7636 - mae: 2.4815 - val_loss: 9.5943 - val_mae: 2.4167
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2000 - mae: 2.4452 - val_loss: 9.6478 - val_mae: 2.4259
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3253 - mae: 2.4490 - val_loss: 9.3296 - val_mae: 2.3675
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3396 - mae: 2.4400 - val_loss: 9.5007 - val_mae: 2.4006
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2813 - mae: 2.4340 - val_loss: 9.3162 - val_mae: 2.3653
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0500 - mae: 2.4055 - val_loss: 9.4860 - val_mae: 2.3973
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3803 - mae: 2.4499 - val_loss: 9.3117 - val_mae: 2.3648
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0610 - mae: 2.3922 - val_loss: 9.3635 - val_mae: 2.3764
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0738 - mae: 2.3994 - val_loss: 9.4751 - val_mae: 2.3876
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1487 - mae: 2.4112 - val_loss: 9.5087 - val_mae: 2.4028
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0388 - mae: 2.4136 - val_loss: 10.4482 - val_mae: 2.5496
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4526 - mae: 2.4747 - val_loss: 9.4951 - val_mae: 2.4004
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6128 - mae: 2.4762 - val_loss: 9.2770 - val_mae: 2.3616
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5744 - mae: 2.4771 - val_loss: 9.2687 - val_mae: 2.3601
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8568 - mae: 2.3760 - val_loss: 9.7432 - val_mae: 2.4446
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1065 - mae: 2.4270 - val_loss: 9.7113 - val_mae: 2.4393
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1188 - mae: 2.4159 - val_loss: 9.6197 - val_mae: 2.4225
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0535 - mae: 2.4090 - val_loss: 9.8672 - val_mae: 2.4648
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1494 - mae: 2.4244 - val_loss: 9.2441 - val_mae: 2.3591
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1194 - mae: 2.4064 - val_loss: 9.2547 - val_mae: 2.3595
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8583 - mae: 2.3826 - val_loss: 9.2171 - val_mae: 2.3548
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0584 - mae: 2.4164 - val_loss: 9.2286 - val_mae: 2.3568
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9627 - mae: 2.3905 - val_loss: 9.2256 - val_mae: 2.3572
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9773 - mae: 2.3869 - val_loss: 9.3605 - val_mae: 2.3801
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1174 - mae: 2.4170 - val_loss: 9.2462 - val_mae: 2.3611
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9127 - mae: 2.3974 - val_loss: 9.5109 - val_mae: 2.4050
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0355 - mae: 2.4111 - val_loss: 9.2066 - val_mae: 2.3546
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1261 - mae: 2.4001 - val_loss: 10.1728 - val_mae: 2.4958
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9438 - mae: 2.3748 - val_loss: 9.1698 - val_mae: 2.3490
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8347 - mae: 2.3596 - val_loss: 9.1504 - val_mae: 2.3459
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8001 - mae: 2.3586 - val_loss: 9.1722 - val_mae: 2.3497
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7331 - mae: 2.3544 - val_loss: 10.1474 - val_mae: 2.5066
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3393 - mae: 2.4421 - val_loss: 9.3958 - val_mae: 2.3869
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9102 - mae: 2.3952 - val_loss: 9.5215 - val_mae: 2.4075
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9760 - mae: 2.3893 - val_loss: 9.2714 - val_mae: 2.3623
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1112 - mae: 2.4094 - val_loss: 9.8729 - val_mae: 2.4659

# %%
# %tensorboard --logdir ./data/logs --port=8088
# Out:
#       <iframe id="tensorboard-frame-d2ece2c88852e046" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d2ece2c88852e046");
#           const url = new URL("/", window.location);
#           const port = 8088;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 23644
# Out:
# "kill" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
